# %%
import numpy as np
from scipy import stats
from pprint import pprint
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pprint import pprint

# %matplotlib inline
# notebook
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = (32.0, 24.0)
pylab.rcParams['font.size'] = 24


A = np.array([[2,3], [4,-1], [5,6]])
B = np.array([[5, 2], [8, 9], [2, 1]])
C = B.T
D = A@C
E = np.sum(A + B)
F = np.mean(A + B)
G = np.var(A + B)
H = np.loadtxt("data.dat", delimiter = ',')

fig, ax = plt.subplots()
ax.scatter(H[:, 0], H[:, 1])
plt.show()

fig, ax = plt.subplots(subplot_kw={'projection' : '3d'})
ax.scatter(H[:, 1], H[:, 2], H[:, 3])
plt.show()

plt.hist(H[:, 0])


L = np.random.normal(0, 5, 1000)

pprint(L)
# Out:
# array([  3.79729117,  -2.25939085, -10.36223054,  -2.49957582,
#        -11.23611737,  10.07013749,  -1.11508674,  -2.12997555,
#         -8.28100271,  -5.45694597,  -5.97684539,  -8.46331511,
#        -11.29888835,  -4.85778973,  -4.83365481,  11.16572269,
#          1.33709169,   5.0711272 ,  -1.05046927,   3.42736814,
#          4.40286616,   0.46381978,  -6.3049967 ,   4.76414628,
#          2.80686263,  -0.30346526,  -6.83517136,   0.57837061,
#          2.82402323,  -1.86086429,  -8.73926514,  -4.04480303,
#          6.58938729,  -2.22273343,   0.07937365,  -2.17155075,
#         -3.51747891,   3.20006015,   6.42132928,   1.56023213,
#          3.45300104,   1.10850786,  -1.73661583,   1.53281554,
#          3.73217938,  -2.54274885,   7.22392334,  -0.66193981,
#         -0.16270022,  -0.78643593,  -2.90917052,  -2.32974672,
#         -3.56287843,  -0.8052153 ,  -2.94591149,  -2.10588154,
#          1.09083316,   0.86254177,  -9.62945145,  -0.43136366,
#         -7.86470306,   3.62179432,   8.28719663,  -4.648647  ,
#          0.27780764,   1.20928307,  -3.21438597,  -3.06528124,
#         -3.47011254,  -0.84321517,   4.85240484,   1.1025374 ,
#          3.94147474,  -5.39599373,   1.41599972, -13.44644187,
#         -0.67752012,  -3.30992339,  -0.95222332,  -8.74369062,
#         -4.24307414,   1.15023499,  -1.00575024,  -2.19279214,
#         -3.94109012,  -0.22889479,  -0.13713897,  -0.56916041,
#         -6.73645417,   1.39638635,  -6.11983526,   4.32320103,
#          7.33854071,   7.34997651,  -3.8094431 ,  -2.2589386 ,
#          3.39222596,   8.65246658,   0.36100958,   0.69716323])
